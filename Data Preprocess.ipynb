# %%
#importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
#loading the data 
df1 = pd.read_csv('data/tmdb-movies.csv')

# %%
#showing the first 5 rows of the data 
df1.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df1.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
#we will start the data cleaning process by droping the unnecessary columns and showing the first 5 rows
col_list = ['id','popularity','tagline','keywords','homepage','overview','budget_adj',
            'vote_count','vote_average','revenue_adj']
df1 = df1.drop(col_list,1)
df1.head()
# Out:
#      imdb_id     budget     revenue                original_title  \
# 0  tt0369610  150000000  1513528810                Jurassic World
# 1  tt1392190  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446  110000000   295238201                     Insurgent
# 3  tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# ...

# %%
#from here we can see that there are alot of missing values especially in the "production_companies" column
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               10856 non-null  object
#  1   budget                10866 non-null  int64
#  2   revenue               10866 non-null  int64
#  3   original_title        10866 non-null  object
#  4   cast                  10790 non-null  object
#  5   director              10822 non-null  object
#  6   runtime               10866 non-null  int64
#  7   genres                10843 non-null  object
#  8   production_companies  9836 non-null   object
#  9   release_date          10866 non-null  object
#  10  release_year          10866 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 933.9+ KB

# %%
#we can see that there are avlues that have non-realist values
df1['budget'].min()
# Out:
# 0

# %%
df1['revenue'].min()
# Out:
# 0

# %%
df1['runtime'].min()
# Out:
# 0

# %%
# we can see that the having a 0 budget, or revenue, or runtime is not realistic, so we need to get rid of these values
#first we replace all the 0 values in these columns by np.nan
df1['budget'] = df1['budget'].replace(0,np.nan)
df1['revenue'] = df1['revenue'].replace(0,np.nan)
df1['runtime'] = df1['runtime'].replace(0,np.nan)

# %%
#second we drop all the rows that have np.nan vales
df1.dropna(inplace = True)

# %%
#now we are going to check for the duplicates 
#first let see how many duplicate rows we have
print(sum(df1.duplicated()))
# Out:
# 1

# %%
#we can see that there is only 1 duplicates
#now we are going to drop that duplicate row and reset the index of the dataframe
df1.drop_duplicates(keep = 'first',inplace = True)
df1 = df1.reset_index(drop = True)

# %%
print(sum(df1.duplicated()))
# Out:
# 0

# %%
# we can see that all the data types are good except for the (release_date) column since we want this column to be a datatime
#object not a string
df1['release_date'] = pd.to_datetime(df1['release_date'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805 entries, 0 to 3804
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               3805 non-null   object
#  1   budget                3805 non-null   float64
#  2   revenue               3805 non-null   float64
#  3   original_title        3805 non-null   object
#  4   cast                  3805 non-null   object
#  5   director              3805 non-null   object
#  6   runtime               3805 non-null   float64
#  7   genres                3805 non-null   object
#  8   production_companies  3805 non-null   object
#  9   release_date          3805 non-null   datetime64[ns]
#  10  release_year          3805 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 327.1+ KB

# %%
#first we need to calculate the profit
df1['profit'] = df1['revenue'] - df1['budget']
print(df1['profit'].max() , df1['profit'].min())
# Out:
# 2544505847.0 -413912431.0

# %%
df2 = pd.read_csv('data/IMDb_movies.csv')
# Out:
# C:\Users\sreda\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
df2.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['imdb_id', 'budget', 'revenue', 'original_title', 'cast', 'director',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'release_year', 'profit'],
#       dtype='object')

# %%
df2 = df2.drop(['title', 'original_title', 'year', 'date_published',
       'genre', 'duration', 'language', 'director', 'writer',
       'production_company', 'actors', 'description', 'votes',
       'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
       'reviews_from_users', 'reviews_from_critics'],1)

df2.head()
# Out:
#   imdb_title_id           country  avg_vote
# 0     tt0000009               USA       5.9
# 1     tt0000574         Australia       6.1
# 2     tt0001892  Germany, Denmark       5.8
# 3     tt0002101               USA       5.2
# 4     tt0002130             Italy       7.0

# %%
df2.shape
# Out:
# (85855, 3)

# %%
df_join = pd.merge(df1,df2,how='inner',left_on=['imdb_id'],right_on=['imdb_title_id'])

# %%
df_join.shape
# Out:
# (3746, 15)

# %%
df_join.head()
# Out:
#      imdb_id       budget       revenue                original_title  \
# 0  tt0369610  150000000.0  1.513529e+09                Jurassic World
# 1  tt1392190  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2  tt2908446  110000000.0  2.952382e+08                     Insurgent
# 3  tt2488496  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4  tt2820852  190000000.0  1.506249e+09                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0    124.0  Action|Adventure|Science Fiction|Thriller
# ...

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3746 entries, 0 to 3745
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               3746 non-null   object
#  1   budget                3746 non-null   float64
#  2   revenue               3746 non-null   float64
#  3   original_title        3746 non-null   object
#  4   cast                  3746 non-null   object
#  5   director              3746 non-null   object
#  6   runtime               3746 non-null   float64
#  7   genres                3746 non-null   object
#  8   production_companies  3746 non-null   object
#  9   release_date          3746 non-null   datetime64[ns]
#  10  release_year          3746 non-null   int64
#  11  profit                3746 non-null   float64
#  12  imdb_title_id         3746 non-null   object
#  13  country               3746 non-null   object
# ...

# %%
df_join = df_join.drop(['cast','imdb_title_id','revenue','runtime','budget'],1)

# %%
# df_join[['original_title','director']] =df_join[['original_title_x','director_x']] 
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3746 entries, 0 to 3745
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               3746 non-null   object
#  1   original_title        3746 non-null   object
#  2   director              3746 non-null   object
#  3   genres                3746 non-null   object
#  4   production_companies  3746 non-null   object
#  5   release_date          3746 non-null   datetime64[ns]
#  6   release_year          3746 non-null   int64
#  7   profit                3746 non-null   float64
#  8   country               3746 non-null   object
#  9   avg_vote              3746 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 321.9+ KB

# %%
df_join.head()
# Out:
#      imdb_id                original_title          director  \
# 0  tt0369610                Jurassic World   Colin Trevorrow
# 1  tt1392190            Mad Max: Fury Road     George Miller
# 2  tt2908446                     Insurgent  Robert Schwentke
# 3  tt2488496  Star Wars: The Force Awakens       J.J. Abrams
# 4  tt2820852                     Furious 7         James Wan
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# ...

# %%
final_data = df_join

# %%
#showing 5 movies with the biggest losses
final_data.sort_values(by=['profit'],ascending=False).head()
# Out:
#         imdb_id                original_title         director  \
# 340   tt0499549                        Avatar    James Cameron
# 3     tt2488496  Star Wars: The Force Awakens      J.J. Abrams
# 1715  tt0120338                       Titanic    James Cameron
# 0     tt0369610                Jurassic World  Colin Trevorrow
# 4     tt2820852                     Furious 7        James Wan
#
#                                          genres  \
# 340    Action|Adventure|Fantasy|Science Fiction
# 3      Action|Adventure|Science Fiction|Fantasy
# 1715                     Drama|Romance|Thriller
# 0     Action|Adventure|Science Fiction|Thriller
# 4                         Action|Crime|Thriller
#
#                                    production_companies release_date  \
# 340   Ingenious Film Partners|Twentieth Century Fox ...   2009-12-10
# 3             Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15
# 1715  Paramount Pictures|Twentieth Century Fox Film ...   1997-11-18
# ...

# %%
final_data['year'] = pd.DatetimeIndex(final_data['release_date']).year

# %%
final_data.head()
# Out:
#      imdb_id                original_title          director  \
# 0  tt0369610                Jurassic World   Colin Trevorrow
# 1  tt1392190            Mad Max: Fury Road     George Miller
# 2  tt2908446                     Insurgent  Robert Schwentke
# 3  tt2488496  Star Wars: The Force Awakens       J.J. Abrams
# 4  tt2820852                     Furious 7         James Wan
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# ...

# %%
# df.drop(['runtime','revenue','budget','release_date','year'],1,inplace  = True)

# %%
# df = df_join
final_data.to_csv('data/IMDb movies.csv',index=False)

# %%
final_data.head()
# Out:
#      imdb_id                original_title          director  \
# 0  tt0369610                Jurassic World   Colin Trevorrow
# 1  tt1392190            Mad Max: Fury Road     George Miller
# 2  tt2908446                     Insurgent  Robert Schwentke
# 3  tt2488496  Star Wars: The Force Awakens       J.J. Abrams
# 4  tt2820852                     Furious 7         James Wan
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18
# ...

# %%
#movies and profits vs year
moviesVsYear = final_data.groupby('release_year',as_index = False).agg({'original_title':'count'})

# %%
moviesVsYear.head()
# Out:
#    release_year  original_title
# 0          1960               5
# 1          1961              10
# 2          1962               7
# 3          1963               6
# 4          1964               7

# %%
moviesVsYear.to_csv('data/moviesVsYears.csv')

# %%
final_data['director'] = final_data['director'].str.split('|')
directors=final_data.explode('director')

# %%
#Top profitable director
directors = directors.groupby(['director','release_year'], as_index = False)['profit'].sum()

# %%
directors.sort_values(by = 'profit', inplace = True, ascending = False)

# %%
directors.head()
# Out:
#              director  release_year        profit
# 1420    James Cameron          2009  2.544506e+09
# 1392      J.J. Abrams          2015  1.868178e+09
# 1419    James Cameron          1997  1.645034e+09
# 634   Colin Trevorrow          2015  1.363529e+09
# 1469        James Wan          2015  1.316249e+09

# %%
directors.to_csv('data/directors.csv')

# %%
movies = final_data[['original_title','release_year','profit']].sort_values(by = 'profit' , ascending = False)

# %%
movies.head()
# Out:
#                     original_title  release_year        profit
# 340                         Avatar          2009  2.544506e+09
# 3     Star Wars: The Force Awakens          2015  1.868178e+09
# 1715                       Titanic          1997  1.645034e+09
# 0                   Jurassic World          2015  1.363529e+09
# 4                        Furious 7          2015  1.316249e+09

# %%
movies.to_csv('data/movies.csv')

# %%
#top profitable companies
final_data['production_companies'] = final_data['production_companies'].str.split('|')

# %%
final_data['num'] = final_data['production_companies'].map(len)

# %%
final_data['profit'] = final_data['profit']/final_data['num']

# %%
comp = final_data.explode('production_companies')

# %%
comp.head()
# Out:
#      imdb_id  original_title           director  \
# 0  tt0369610  Jurassic World  [Colin Trevorrow]
# 0  tt0369610  Jurassic World  [Colin Trevorrow]
# 0  tt0369610  Jurassic World  [Colin Trevorrow]
# 0  tt0369610  Jurassic World  [Colin Trevorrow]
# 0  tt0369610  Jurassic World  [Colin Trevorrow]
#
#                                       genres     production_companies  \
# 0  Action|Adventure|Science Fiction|Thriller        Universal Studios
# 0  Action|Adventure|Science Fiction|Thriller     Amblin Entertainment
# 0  Action|Adventure|Science Fiction|Thriller       Legendary Pictures
# 0  Action|Adventure|Science Fiction|Thriller  Fuji Television Network
# 0  Action|Adventure|Science Fiction|Thriller                   Dentsu
#
#   release_date  release_year       profit country  avg_vote  year  num
# 0   2015-06-09          2015  272705762.0     USA       7.0  2015    5
# 0   2015-06-09          2015  272705762.0     USA       7.0  2015    5
# ...

# %%
comp = comp.groupby(['production_companies','release_year'],as_index = False)['profit'].sum()

# %%
comp.to_csv('data/companies.csv')

# %%
final_data['genres'] = final_data['genres'].str.split('|')
genres=final_data.explode('genres')

# %%
#Top profitable director
genres = genres.groupby(['genres','release_year'], as_index = False).agg({'profit':'mean'})

# %%
genres.sort_values(by = 'profit', inplace = True, ascending = False)

# %%
genres.head()
# Out:
#         genres  release_year       profit
# 126  Animation          1992  476050219.0
# 455     Horror          1973  216653072.5
# 111  Animation          1961  211880014.0
# 112  Animation          1967  201843612.0
# 800    Western          1990  201104424.0

# %%
genres.to_csv('data/genres.csv')

# %%
import calendar

# %%
final_data.head()
# Out:
#      imdb_id                original_title            director  \
# 0  tt0369610                Jurassic World   [Colin Trevorrow]
# 1  tt1392190            Mad Max: Fury Road     [George Miller]
# 2  tt2908446                     Insurgent  [Robert Schwentke]
# 3  tt2488496  Star Wars: The Force Awakens       [J.J. Abrams]
# 4  tt2820852                     Furious 7         [James Wan]
#
#                                            genres  \
# 0  [Action, Adventure, Science Fiction, Thriller]
# 1  [Action, Adventure, Science Fiction, Thriller]
# 2          [Adventure, Science Fiction, Thriller]
# 3   [Action, Adventure, Science Fiction, Fantasy]
# 4                       [Action, Crime, Thriller]
#
#                                 production_companies release_date  \
# 0  [Universal Studios, Amblin Entertainment, Lege...   2015-06-09
# 1  [Village Roadshow Pictures, Kennedy Miller Pro...   2015-05-13
# 2  [Summit Entertainment, Mandeville Films, Red W...   2015-03-18
# ...

# %%
rating=final_data[['imdb_id','original_title','release_year','avg_vote']]
rating
# Out:
#         imdb_id                   original_title  release_year  avg_vote
# 0     tt0369610                   Jurassic World          2015       7.0
# 1     tt1392190               Mad Max: Fury Road          2015       8.1
# 2     tt2908446                        Insurgent          2015       6.2
# 3     tt2488496     Star Wars: The Force Awakens          2015       7.9
# 4     tt2820852                        Furious 7          2015       7.1
# ...         ...                              ...           ...       ...
# 3741  tt0061184  Who's Afraid of Virginia Woolf?          1966       8.0
# 3742  tt0061107                     Torn Curtain          1966       6.7
# 3743  tt0061619                        El Dorado          1966       7.6
# 3744  tt0060934                 The Sand Pebbles          1966       7.6
# 3745  tt0060397                 Fantastic Voyage          1966       6.8
#
# [3746 rows x 4 columns]

# %%
rating.sort_values(by ='avg_vote', inplace = True, ascending = False)
# Out:
# <ipython-input-163-b2741291f08b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating.sort_values(by ='avg_vote', inplace = True, ascending = False)

# %%
rating.to_csv('data/rating')

# %%
final_data['country'] = final_data['country'].str.split(',')
country=final_data.explode('country')
country['country']=country['country'].str.strip()

# %%
country2 = country[['imdb_id','original_title','release_year','country']]

# %%
country2=country2.groupby('country').agg({'original_title':'count'})

# %%
country2 = country2.sort_values('original_title',ascending=False)

# %%
country2.to_csv('data/country.csv')

# %%
country2
# Out:
#                original_title
# country
# USA                      3469
# UK                        667
# Germany                   318
# France                    305
# Canada                    304
# ...                       ...
# Liechtenstein               1
# Algeria                     1
# Namibia                     1
# Qatar                       1
# Lithuania                   1
#
# [74 rows x 1 columns]
